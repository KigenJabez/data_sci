# %%
import pandas as pd
data = pd.read_csv('/Users/kigenkipyego/Desktop/vscode/Jupyter Demo/orders.csv')
data.tail()
# Out:
#     order_id  customer_id  product_id           product_name     category  \
# 45      1046         2046        3046  Instant Pot (6 Quart)         home
# 46      1047         2047        3047          Pair of Socks     clothing
# 47      1048         2048        3048    Set of Mixing Bowls         home
# 48      1049         2049        3049       Wireless Charger  electronics
# 49      1050         2050        3050            Men's Watch  accessories
#
#      price  order_date           city  country
# 45   89.99  2023-06-15  San Francisco      USA
# 46    4.50  2023-06-16        Chicago      USA
# 47   24.99  2023-06-17    Los Angeles      USA
# 48   19.99  2023-06-18       New York      USA
# 49  149.99  2023-06-19         Berlin  Germany

# %%
#checking for the number of the rows and columns
row,column = data.shape
print(row)
print(column)
print(f"Rows:{row}\ncolumn:{column}")
# Out:
# 50
# 9
# Rows:50
# column:9

# %%
# checking columns
data.columns
# Out:
# Index(['order_id', 'customer_id', 'product_id', 'product_name', 'category',
#        'price', 'order_date', 'city', 'country'],
#       dtype='object')

# %%
data.keys()
# Out:
# Index(['order_id', 'customer_id', 'product_id', 'product_name', 'category',
#        'price', 'order_date', 'city', 'country'],
#       dtype='object')

# %%
#setting index
data.set_index("order_id" ,inplace= True)
data.head()
# Out:
#           customer_id  product_id                  product_name     category  \
# order_id
# 1001             2001        3001            Men's Cotton Shirt     clothing
# 1002             2002        3002  Gaming Laptop (i7 Processor)  electronics
# 1003             2003        3003     Box of Pencils (12 count)   stationery
# 1004             2004        3004           Fresh Apples (1 kg)      grocery
# 1005             2005        3005                    Travel Mug         home
#
#            price  order_date           city country
# order_id
# 1001       24.99  2023-05-01       New York     USA
# 1002      899.99  2023-05-02    Los Angeles     USA
# 1003        2.50  2023-05-03        Chicago     USA
# 1004        5.99  2023-05-04  San Francisco     USA
# 1005      -19.95  2023-05-05         Austin     USA

# %%
#checking the data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1001 to 1050
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   50 non-null     int64
#  1   product_id    50 non-null     int64
#  2   product_name  50 non-null     object
#  3   category      50 non-null     object
#  4   price         49 non-null     float64
#  5   order_date    49 non-null     object
#  6   city          50 non-null     object
#  7   country       50 non-null     object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.5+ KB

# %%
#checking statistics summary
data.describe()
# Out:
#        customer_id  product_id       price
# count     50.00000    50.00000   49.000000
# mean    2025.50000  3025.50000   61.478163
# std       14.57738    14.57738  140.308495
# min     2001.00000  3001.00000  -19.950000
# 25%     2013.25000  3013.25000    7.990000
# 50%     2025.50000  3025.50000   24.990000
# 75%     2037.75000  3037.75000   50.000000
# max     2050.00000  3050.00000  899.990000

# %%
#checking missing values
data.isnull()
data.isnull().sum()/len(data)*100
# Out:
# customer_id     0.0
# product_id      0.0
# product_name    0.0
# category        0.0
# price           2.0
# order_date      2.0
# city            0.0
# country         0.0
# dtype: float64

# %%
len(data)
# Out:
# 50

# %%
import numpy as np
data["price"] = data["price"].fillna(56.98)
data["price"].isna().sum()
data
# Out:
#           customer_id  product_id                  product_name     category  \
# order_id
# 1001             2001        3001            Men's Cotton Shirt     clothing
# 1002             2002        3002  Gaming Laptop (i7 Processor)  electronics
# 1003             2003        3003     Box of Pencils (12 count)   stationery
# 1004             2004        3004           Fresh Apples (1 kg)      grocery
# 1005             2005        3005                    Travel Mug         home
# 1006             2006        3006             10oz Coffee Beans      grocery
# 1007             2007        3007       Running Shoes (women's)     clothing
# 1008             2008        3008               12 Pack of Soda      grocery
# 1009             2009        3009         Headphones (wireless)  electronics
# 1010             2010        3010                  Office Chair    furniture
# 1011             2011        3011      Box of Markers (24 pack)   stationery
# ...

# %%
#converting to data in format
data['order_date']= pd.to_datetime(data['order_date'], errors="coerce")

# %%
#extracting date components
data['order_month']= data['order_date'].dt.month
data['order_day']= data['order_date'].dt.day
data['order_year']= data['order_date'].dt.year

# %%
#dropping a column name, 
#axis = 1 -column , axis = 0 - row
data.drop("order_date", axis=1)
# Out:
#           customer_id  product_id                  product_name     category  \
# order_id
# 1001             2001        3001            Men's Cotton Shirt     clothing
# 1002             2002        3002  Gaming Laptop (i7 Processor)  electronics
# 1003             2003        3003     Box of Pencils (12 count)   stationery
# 1004             2004        3004           Fresh Apples (1 kg)      grocery
# 1005             2005        3005                    Travel Mug         home
# 1006             2006        3006             10oz Coffee Beans      grocery
# 1007             2007        3007       Running Shoes (women's)     clothing
# 1008             2008        3008               12 Pack of Soda      grocery
# 1009             2009        3009         Headphones (wireless)  electronics
# 1010             2010        3010                  Office Chair    furniture
# 1011             2011        3011      Box of Markers (24 pack)   stationery
# ...

# %%
#Groupby calculates sum(),median() or mode() depending on a colum
data.groupby(['city'])['price'].sum()
# Out:
# city
# Austin            160.00
# Berlin            346.92
# Chicago           139.46
# Los Angeles      1510.46
# New York          256.94
# San Francisco     199.67
# Seattle           455.96
# Name: price, dtype: float64

# %%
type(data['price'])
# Out:
# pandas.core.series.Series

# %%
data['order_date'].sort_values()
# Out:
# order_id
# 1001   2023-05-01
# 1002   2023-05-02
# 1003   2023-05-03
# 1004   2023-05-04
# 1005   2023-05-05
# 1006   2023-05-06
# 1009   2023-05-09
# 1010   2023-05-10
# 1011   2023-05-11
# 1012   2023-05-12
# 1013   2023-05-13
# 1014   2023-05-14
# 1015   2023-05-15
# 1016   2023-05-16
# 1017   2023-05-17
# 1018   2023-05-18
# 1019   2023-05-19
# 1020   2023-05-20
# 1021   2023-05-21
# 1022   2023-05-22
# 1023   2023-05-23
# 1024   2023-05-24
# 1025   2023-05-25
# 1026   2023-05-26
# 1027   2023-05-27
# 1029   2023-05-29
# 1030   2023-05-30
# 1031   2023-05-31
# 1032   2023-06-01
# 1033   2023-06-02
# 1034   2023-06-03
# 1035   2023-06-04
# 1036   2023-06-05
# 1037   2023-06-06
# 1038   2023-06-07
# 1039   2023-06-08
# 1040   2023-06-09
# 1041   2023-06-10
# 1042   2023-06-11
# 1043   2023-06-12
# 1044   2023-06-13
# 1045   2023-06-14
# 1046   2023-06-15
# 1047   2023-06-16
# 1048   2023-06-17
# 1049   2023-06-18
# 1050   2023-06-19
# 1007          NaT
# 1008          NaT
# ...

# %%
data.describe()
# Out:
#        customer_id  product_id       price                     order_date  \
# count     50.00000    50.00000   50.000000                             47
# mean    2025.50000  3025.50000   61.388200  2023-05-26 05:06:22.978723328
# min     2001.00000  3001.00000  -19.950000            2023-05-01 00:00:00
# 25%     2013.25000  3013.25000    8.240000            2023-05-14 12:00:00
# 50%     2025.50000  3025.50000   24.990000            2023-05-26 00:00:00
# 75%     2037.75000  3037.75000   50.000000            2023-06-07 12:00:00
# max     2050.00000  3050.00000  899.990000            2023-06-19 00:00:00
# std       14.57738    14.57738  138.870853                            NaN
#
#        order_month  order_day  order_year
# count    47.000000  47.000000        47.0
# mean      5.404255  13.680851      2023.0
# min       5.000000   1.000000      2023.0
# 25%       5.000000   6.500000      2023.0
# 50%       5.000000  13.000000      2023.0
# 75%       6.000000  19.000000      2023.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1001 to 1050
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   50 non-null     int64
#  1   product_id    50 non-null     int64
#  2   product_name  50 non-null     object
#  3   category      50 non-null     object
#  4   price         50 non-null     float64
#  5   order_date    47 non-null     datetime64[ns]
#  6   city          50 non-null     object
#  7   country       50 non-null     object
#  8   order_month   47 non-null     float64
#  9   order_day     47 non-null     float64
#  10  order_year    47 non-null     float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(4)
# memory usage: 4.7+ KB

# %%
data.isna()
# Out:
#           customer_id  product_id  product_name  category  price  order_date  \
# order_id
# 1001            False       False         False     False  False       False
# 1002            False       False         False     False  False       False
# 1003            False       False         False     False  False       False
# 1004            False       False         False     False  False       False
# 1005            False       False         False     False  False       False
# 1006            False       False         False     False  False       False
# 1007            False       False         False     False  False        True
# 1008            False       False         False     False  False        True
# 1009            False       False         False     False  False       False
# 1010            False       False         False     False  False       False
# 1011            False       False         False     False  False       False
# ...

# %%
#filling missing values
data['order_date'] = data['order_date'].fillna(data['order_date'].mean())

# %%
data.isna()
# Out:
#           customer_id  product_id  product_name  category  price  order_date  \
# order_id
# 1001            False       False         False     False  False       False
# 1002            False       False         False     False  False       False
# 1003            False       False         False     False  False       False
# 1004            False       False         False     False  False       False
# 1005            False       False         False     False  False       False
# 1006            False       False         False     False  False       False
# 1007            False       False         False     False  False       False
# 1008            False       False         False     False  False       False
# 1009            False       False         False     False  False       False
# 1010            False       False         False     False  False       False
# 1011            False       False         False     False  False       False
# ...

# %%
data.drop(1028,  axis=0)
data.drop(1007, )
